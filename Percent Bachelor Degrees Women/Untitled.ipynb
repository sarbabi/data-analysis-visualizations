# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
women_degrees = pd.read_csv("percent-bachelors-degrees-women-usa.csv")
print(women_degrees.columns)
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
ax.plot(women_degrees["Year"], women_degrees["Biology"])
ax.set_title("Percentage of women students graduated whith 'Biology' major each year since 1970")
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(women_degrees["Year"], women_degrees["Biology"], c="blue", label="Women")
ax.plot(women_degrees["Year"], 100 - women_degrees["Biology"], c="green", label="Men")
ax.set_title("Percentage of Biology Degrees Awarded By Gender")
ax.legend(loc="upper right")
plt.show()

# %%
#in order to incread data-ink ration we are going to hide tick marks
fig,ax = plt.subplots()
ax.plot(women_degrees["Year"], women_degrees["Biology"], c="blue", label="Women")
ax.plot(women_degrees["Year"], 100 - women_degrees["Biology"], c="green", label="Men")
ax.tick_params(bottom=False, top=False, left=False, right=False)
ax.set_title("Percentage of Biology Degrees Awarded By Gender")
ax.legend(loc="upper right")
plt.show()

# %%
#more increase in data-ink ration by hiding spines
fig,ax = plt.subplots()
ax.plot(women_degrees["Year"], women_degrees["Biology"], c="blue", label="Women")
ax.plot(women_degrees["Year"], 100 - women_degrees["Biology"], c="green", label="Men")
ax.tick_params(bottom=False, top=False, left=False, right=False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.set_title("Percentage of Biology Degrees Awarded By Gender")
ax.legend(loc="upper right")
plt.show()

# %%
#comparing gender gap access degree categories in 4 subplots for STEM majors
fig = plt.figure(figsize=(20, 20))
majors = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']
for i,major in enumerate(majors):
    ax = fig.add_subplot(2, 2, i+1)
    ax.plot(women_degrees['Year'], women_degrees[major], c='blue', label='Women')
    ax.plot(women_degrees['Year'], 100 - women_degrees[major], c='green', label='Men')
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom=False, top=False, right=False, left=False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_title(major)
    ax.legend(loc='upper right')
plt.show()
